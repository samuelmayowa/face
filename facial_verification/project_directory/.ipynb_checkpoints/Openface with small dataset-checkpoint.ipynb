# %%
import numpy as np
import pandas as pd

import tensorflow as tf
import keras
from keras.models import Sequential, Model
from keras.layers import Conv2D, ZeroPadding2D, Activation, Input, concatenate
from keras.layers.core import Dense, Activation, Lambda, Flatten
from keras.layers.normalization import BatchNormalization
from keras import backend as K
from keras.layers.pooling import MaxPooling2D, AveragePooling2D
from keras.layers.merge import Concatenate
from keras.models import load_model
from keras.models import model_from_json
from keras.preprocessing.image import load_img, save_img, img_to_array
from keras.preprocessing import image
from keras.applications.imagenet_utils import preprocess_input
from keras.preprocessing.image import ImageDataGenerator

import os
import utils
from utils import LRN2D

import matplotlib.pyplot as plt

import warnings
plt.style.use('fivethirtyeight')
plt.rcParams['figure.figsize'] = [8, 4]
warnings.filterwarnings("ignore", category=FutureWarning)
# %config InlineBackend.figure_format = 'retina'

# %%
class IdentityMetadata():
    def __init__(self, base, name, file):
        # dataset base directory
        self.base = base
        # identity name
        self.name = name
        # image file name
        self.file = file

    def __repr__(self):
        return self.image_path()

    def image_path(self):
        return os.path.join(self.base, self.name, self.file)

# %%
def extensions(path):
    extension = []
    for i in os.listdir(path):
        for f in os.listdir(os.path.join(path, i)):
            ext = os.path.splitext(f)[1]
            extension.append(ext)
    return np.array(extension)

extension = extensions('images')

# %%
(pd.Series(extension)).value_counts()
# Out:
# .jpg    164
# dtype: int64

# %%
def load_metadata(path):
  metadata = []
  for i in os.listdir(path):
    for f in os.listdir(os.path.join(path, i)):
      ext = os.path.splitext(f)[1]
      if ext == '.jpg' or ext == '.jpeg' or ext=='.JPG' or ext=='.png':
        metadata.append(IdentityMetadata(path, i, f))
  return np.array(metadata)

metadata = load_metadata('images')

# %%
len(metadata)
# Out:
# 164

# %%
metadata[0]
# Out:
# images\adeolu\adeolu_0_1416.jpg

# %%
names = np.array([m.name for m in metadata])

# %%
pd.Series(names).value_counts()[:5]
# Out:
# demola    41
# laide     41
# adeolu    41
# labake    41
# dtype: int64

# %%
plt.figure(figsize=(20,6))
plt.plot(pd.Series(names).value_counts())
plt.xticks(rotation=90)
plt.grid(b=True)
plt.show()

# %%
# Setting the input size now to 64 x 64 pixel 
# Setting the input size now to 96 x 96 pixel 
img_rows = 96
img_cols = 96 
epochs = 300
batch_size = 16

# %%
if K.image_data_format() == 'channels_first':
    input_shape = (3, img_cols, img_rows) 
else:
    input_shape = (img_cols, img_rows, 3)

# %% [markdown]
# ### For the OpenFace We loaded the pretrained model like so since it is not inbuilt in Keras

# %%
def model_creator(top_model):
    myInput = Input(shape=(96, 96, 3))

    x = ZeroPadding2D(padding=(3, 3), input_shape=(96, 96, 3))(myInput)
    x = Conv2D(64, (7, 7), strides=(2, 2), name='conv1')(x)
    x = BatchNormalization(axis=3, epsilon=0.00001, name='bn1')(x)
    x = Activation('relu')(x)
    x = ZeroPadding2D(padding=(1, 1))(x)
    x = MaxPooling2D(pool_size=3, strides=2)(x)
    x = Lambda(LRN2D, name='lrn_1')(x)
    x = Conv2D(64, (1, 1), name='conv2')(x)
    x = BatchNormalization(axis=3, epsilon=0.00001, name='bn2')(x)
    x = Activation('relu')(x)
    x = ZeroPadding2D(padding=(1, 1))(x)
    x = Conv2D(192, (3, 3), name='conv3')(x)
    x = BatchNormalization(axis=3, epsilon=0.00001, name='bn3')(x)
    x = Activation('relu')(x)
    x = Lambda(LRN2D, name='lrn_2')(x)
    x = ZeroPadding2D(padding=(1, 1))(x)
    x = MaxPooling2D(pool_size=3, strides=2)(x)

    # Inception3a
    inception_3a_3x3 = Conv2D(96, (1, 1), name='inception_3a_3x3_conv1')(x)
    inception_3a_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_3x3_bn1')(inception_3a_3x3)
    inception_3a_3x3 = Activation('relu')(inception_3a_3x3)
    inception_3a_3x3 = ZeroPadding2D(padding=(1, 1))(inception_3a_3x3)
    inception_3a_3x3 = Conv2D(128, (3, 3), name='inception_3a_3x3_conv2')(inception_3a_3x3)
    inception_3a_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_3x3_bn2')(inception_3a_3x3)
    inception_3a_3x3 = Activation('relu')(inception_3a_3x3)

    inception_3a_5x5 = Conv2D(16, (1, 1), name='inception_3a_5x5_conv1')(x)
    inception_3a_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_5x5_bn1')(inception_3a_5x5)
    inception_3a_5x5 = Activation('relu')(inception_3a_5x5)
    inception_3a_5x5 = ZeroPadding2D(padding=(2, 2))(inception_3a_5x5)
    inception_3a_5x5 = Conv2D(32, (5, 5), name='inception_3a_5x5_conv2')(inception_3a_5x5)
    inception_3a_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_5x5_bn2')(inception_3a_5x5)
    inception_3a_5x5 = Activation('relu')(inception_3a_5x5)

    inception_3a_pool = MaxPooling2D(pool_size=3, strides=2)(x)
    inception_3a_pool = Conv2D(32, (1, 1), name='inception_3a_pool_conv')(inception_3a_pool)
    inception_3a_pool = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_pool_bn')(inception_3a_pool)
    inception_3a_pool = Activation('relu')(inception_3a_pool)
    inception_3a_pool = ZeroPadding2D(padding=((3, 4), (3, 4)))(inception_3a_pool)

    inception_3a_1x1 = Conv2D(64, (1, 1), name='inception_3a_1x1_conv')(x)
    inception_3a_1x1 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3a_1x1_bn')(inception_3a_1x1)
    inception_3a_1x1 = Activation('relu')(inception_3a_1x1)

    inception_3a = concatenate([inception_3a_3x3, inception_3a_5x5, inception_3a_pool, inception_3a_1x1], axis=3)

    # Inception3b
    inception_3b_3x3 = Conv2D(96, (1, 1), name='inception_3b_3x3_conv1')(inception_3a)
    inception_3b_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_3x3_bn1')(inception_3b_3x3)
    inception_3b_3x3 = Activation('relu')(inception_3b_3x3)
    inception_3b_3x3 = ZeroPadding2D(padding=(1, 1))(inception_3b_3x3)
    inception_3b_3x3 = Conv2D(128, (3, 3), name='inception_3b_3x3_conv2')(inception_3b_3x3)
    inception_3b_3x3 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_3x3_bn2')(inception_3b_3x3)
    inception_3b_3x3 = Activation('relu')(inception_3b_3x3)

    inception_3b_5x5 = Conv2D(32, (1, 1), name='inception_3b_5x5_conv1')(inception_3a)
    inception_3b_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_5x5_bn1')(inception_3b_5x5)
    inception_3b_5x5 = Activation('relu')(inception_3b_5x5)
    inception_3b_5x5 = ZeroPadding2D(padding=(2, 2))(inception_3b_5x5)
    inception_3b_5x5 = Conv2D(64, (5, 5), name='inception_3b_5x5_conv2')(inception_3b_5x5)
    inception_3b_5x5 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_5x5_bn2')(inception_3b_5x5)
    inception_3b_5x5 = Activation('relu')(inception_3b_5x5)

    inception_3b_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_3a)
    inception_3b_pool = Conv2D(64, (1, 1), name='inception_3b_pool_conv')(inception_3b_pool)
    inception_3b_pool = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_pool_bn')(inception_3b_pool)
    inception_3b_pool = Activation('relu')(inception_3b_pool)
    inception_3b_pool = ZeroPadding2D(padding=(4, 4))(inception_3b_pool)

    inception_3b_1x1 = Conv2D(64, (1, 1), name='inception_3b_1x1_conv')(inception_3a)
    inception_3b_1x1 = BatchNormalization(axis=3, epsilon=0.00001, name='inception_3b_1x1_bn')(inception_3b_1x1)
    inception_3b_1x1 = Activation('relu')(inception_3b_1x1)

    inception_3b = concatenate([inception_3b_3x3, inception_3b_5x5, inception_3b_pool, inception_3b_1x1], axis=3)

    # Inception3c
    inception_3c_3x3 = utils.conv2d_bn(inception_3b,
                                       layer='inception_3c_3x3',
                                       cv1_out=128,
                                       cv1_filter=(1, 1),
                                       cv2_out=256,
                                       cv2_filter=(3, 3),
                                       cv2_strides=(2, 2),
                                       padding=(1, 1))

    inception_3c_5x5 = utils.conv2d_bn(inception_3b,
                                       layer='inception_3c_5x5',
                                       cv1_out=32,
                                       cv1_filter=(1, 1),
                                       cv2_out=64,
                                       cv2_filter=(5, 5),
                                       cv2_strides=(2, 2),
                                       padding=(2, 2))

    inception_3c_pool = MaxPooling2D(pool_size=3, strides=2)(inception_3b)
    inception_3c_pool = ZeroPadding2D(padding=((0, 1), (0, 1)))(inception_3c_pool)

    inception_3c = concatenate([inception_3c_3x3, inception_3c_5x5, inception_3c_pool], axis=3)

    #inception 4a
    inception_4a_3x3 = utils.conv2d_bn(inception_3c,
                                       layer='inception_4a_3x3',
                                       cv1_out=96,
                                       cv1_filter=(1, 1),
                                       cv2_out=192,
                                       cv2_filter=(3, 3),
                                       cv2_strides=(1, 1),
                                       padding=(1, 1))
    inception_4a_5x5 = utils.conv2d_bn(inception_3c,
                                       layer='inception_4a_5x5',
                                       cv1_out=32,
                                       cv1_filter=(1, 1),
                                       cv2_out=64,
                                       cv2_filter=(5, 5),
                                       cv2_strides=(1, 1),
                                       padding=(2, 2))

    inception_4a_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_3c)
    inception_4a_pool = utils.conv2d_bn(inception_4a_pool,
                                        layer='inception_4a_pool',
                                        cv1_out=128,
                                        cv1_filter=(1, 1),
                                        padding=(2, 2))
    inception_4a_1x1 = utils.conv2d_bn(inception_3c,
                                       layer='inception_4a_1x1',
                                       cv1_out=256,
                                       cv1_filter=(1, 1))
    inception_4a = concatenate([inception_4a_3x3, inception_4a_5x5, inception_4a_pool, inception_4a_1x1], axis=3)

    #inception4e
    inception_4e_3x3 = utils.conv2d_bn(inception_4a,
                                       layer='inception_4e_3x3',
                                       cv1_out=160,
                                       cv1_filter=(1, 1),
                                       cv2_out=256,
                                       cv2_filter=(3, 3),
                                       cv2_strides=(2, 2),
                                       padding=(1, 1))
    inception_4e_5x5 = utils.conv2d_bn(inception_4a,
                                       layer='inception_4e_5x5',
                                       cv1_out=64,
                                       cv1_filter=(1, 1),
                                       cv2_out=128,
                                       cv2_filter=(5, 5),
                                       cv2_strides=(2, 2),
                                       padding=(2, 2))
    inception_4e_pool = MaxPooling2D(pool_size=3, strides=2)(inception_4a)
    inception_4e_pool = ZeroPadding2D(padding=((0, 1), (0, 1)))(inception_4e_pool)

    inception_4e = concatenate([inception_4e_3x3, inception_4e_5x5, inception_4e_pool], axis=3)

    #inception5a
    inception_5a_3x3 = utils.conv2d_bn(inception_4e,
                                       layer='inception_5a_3x3',
                                       cv1_out=96,
                                       cv1_filter=(1, 1),
                                       cv2_out=384,
                                       cv2_filter=(3, 3),
                                       cv2_strides=(1, 1),
                                       padding=(1, 1))

    inception_5a_pool = AveragePooling2D(pool_size=(3, 3), strides=(3, 3))(inception_4e)
    inception_5a_pool = utils.conv2d_bn(inception_5a_pool,
                                        layer='inception_5a_pool',
                                        cv1_out=96,
                                        cv1_filter=(1, 1),
                                        padding=(1, 1))
    inception_5a_1x1 = utils.conv2d_bn(inception_4e,
                                       layer='inception_5a_1x1',
                                       cv1_out=256,
                                       cv1_filter=(1, 1))

    inception_5a = concatenate([inception_5a_3x3, inception_5a_pool, inception_5a_1x1], axis=3)

    #inception_5b
    inception_5b_3x3 = utils.conv2d_bn(inception_5a,
                                       layer='inception_5b_3x3',
                                       cv1_out=96,
                                       cv1_filter=(1, 1),
                                       cv2_out=384,
                                       cv2_filter=(3, 3),
                                       cv2_strides=(1, 1),
                                       padding=(1, 1))
    inception_5b_pool = MaxPooling2D(pool_size=3, strides=2)(inception_5a)
    inception_5b_pool = utils.conv2d_bn(inception_5b_pool,
                                        layer='inception_5b_pool',
                                        cv1_out=96,
                                        cv1_filter=(1, 1))
    inception_5b_pool = ZeroPadding2D(padding=(1, 1))(inception_5b_pool)

    inception_5b_1x1 = utils.conv2d_bn(inception_5a,
                                       layer='inception_5b_1x1',
                                       cv1_out=256,
                                       cv1_filter=(1, 1))
    inception_5b = concatenate([inception_5b_3x3, inception_5b_pool, inception_5b_1x1], axis=3)

    av_pool = AveragePooling2D(pool_size=(3, 3), strides=(1, 1))(inception_5b)
    reshape_layer = Flatten()(av_pool)
    dense_layer = Dense(128, name='dense_layer')(reshape_layer)
    norm_layer = Dense(units=4, activation = "sigmoid")(dense_layer)

    return Model(inputs=[myInput], outputs=norm_layer)

# %%
conv_base=model_creator('./models/open_face.h5')

# %%
config = conv_base.get_config() # Returns pretty much every information about your model
print(config["layers"][0]["config"]["batch_input_shape"]) # returns a tuple of width, height and channels
# Out:
# (None, 96, 96, 3)

# %%
print(conv_base.summary())
print('No. of hidden layers after addition of extra layers= {}'.format(len(conv_base.layers)))
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 96, 96, 3)    0
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 102, 102, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1 (Conv2D)                  (None, 48, 48, 64)   9472        zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, 48, 48, 64)   256         conv1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 48, 48, 64)   0           bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_2 (ZeroPadding2D (None, 50, 50, 64)   0           activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 24, 24, 64)   0           zero_padding2d_2[0][0]
# __________________________________________________________________________________________________
# lrn_1 (Lambda)                  (None, 24, 24, 64)   0           max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2 (Conv2D)                  (None, 24, 24, 64)   4160        lrn_1[0][0]
# __________________________________________________________________________________________________
# bn2 (BatchNormalization)        (None, 24, 24, 64)   256         conv2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 24, 24, 64)   0           bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_3 (ZeroPadding2D (None, 26, 26, 64)   0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv3 (Conv2D)                  (None, 24, 24, 192)  110784      zero_padding2d_3[0][0]
# __________________________________________________________________________________________________
# bn3 (BatchNormalization)        (None, 24, 24, 192)  768         conv3[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 24, 24, 192)  0           bn3[0][0]
# __________________________________________________________________________________________________
# lrn_2 (Lambda)                  (None, 24, 24, 192)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_4 (ZeroPadding2D (None, 26, 26, 192)  0           lrn_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 12, 12, 192)  0           zero_padding2d_4[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_conv1 (Conv2D) (None, 12, 12, 96)   18528       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_conv1 (Conv2D) (None, 12, 12, 16)   3088        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_bn1 (BatchNorm (None, 12, 12, 96)   384         inception_3a_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_bn1 (BatchNorm (None, 12, 12, 16)   64          inception_3a_5x5_conv1[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 12, 12, 96)   0           inception_3a_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 12, 12, 16)   0           inception_3a_5x5_bn1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 5, 5, 192)    0           max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_5 (ZeroPadding2D (None, 14, 14, 96)   0           activation_4[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_6 (ZeroPadding2D (None, 16, 16, 16)   0           activation_6[0][0]
# __________________________________________________________________________________________________
# inception_3a_pool_conv (Conv2D) (None, 5, 5, 32)     6176        max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_conv2 (Conv2D) (None, 12, 12, 128)  110720      zero_padding2d_5[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_conv2 (Conv2D) (None, 12, 12, 32)   12832       zero_padding2d_6[0][0]
# __________________________________________________________________________________________________
# inception_3a_pool_bn (BatchNorm (None, 5, 5, 32)     128         inception_3a_pool_conv[0][0]
# __________________________________________________________________________________________________
# inception_3a_1x1_conv (Conv2D)  (None, 12, 12, 64)   12352       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_3a_3x3_bn2 (BatchNorm (None, 12, 12, 128)  512         inception_3a_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# inception_3a_5x5_bn2 (BatchNorm (None, 12, 12, 32)   128         inception_3a_5x5_conv2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 5, 5, 32)     0           inception_3a_pool_bn[0][0]
# __________________________________________________________________________________________________
# inception_3a_1x1_bn (BatchNorma (None, 12, 12, 64)   256         inception_3a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 12, 12, 128)  0           inception_3a_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 12, 12, 32)   0           inception_3a_5x5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_7 (ZeroPadding2D (None, 12, 12, 32)   0           activation_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 12, 12, 64)   0           inception_3a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 12, 12, 256)  0           activation_5[0][0]
#                                                                  activation_7[0][0]
#                                                                  zero_padding2d_7[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_conv1 (Conv2D) (None, 12, 12, 96)   24672       concatenate_1[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_conv1 (Conv2D) (None, 12, 12, 32)   8224        concatenate_1[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_bn1 (BatchNorm (None, 12, 12, 96)   384         inception_3b_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_bn1 (BatchNorm (None, 12, 12, 32)   128         inception_3b_5x5_conv1[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 12, 12, 96)   0           inception_3b_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 12, 12, 32)   0           inception_3b_5x5_bn1[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 4, 4, 256)    0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_8 (ZeroPadding2D (None, 14, 14, 96)   0           activation_10[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_9 (ZeroPadding2D (None, 16, 16, 32)   0           activation_12[0][0]
# __________________________________________________________________________________________________
# inception_3b_pool_conv (Conv2D) (None, 4, 4, 64)     16448       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_conv2 (Conv2D) (None, 12, 12, 128)  110720      zero_padding2d_8[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_conv2 (Conv2D) (None, 12, 12, 64)   51264       zero_padding2d_9[0][0]
# __________________________________________________________________________________________________
# inception_3b_pool_bn (BatchNorm (None, 4, 4, 64)     256         inception_3b_pool_conv[0][0]
# __________________________________________________________________________________________________
# inception_3b_1x1_conv (Conv2D)  (None, 12, 12, 64)   16448       concatenate_1[0][0]
# __________________________________________________________________________________________________
# inception_3b_3x3_bn2 (BatchNorm (None, 12, 12, 128)  512         inception_3b_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# inception_3b_5x5_bn2 (BatchNorm (None, 12, 12, 64)   256         inception_3b_5x5_conv2[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 4, 4, 64)     0           inception_3b_pool_bn[0][0]
# __________________________________________________________________________________________________
# inception_3b_1x1_bn (BatchNorma (None, 12, 12, 64)   256         inception_3b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 12, 12, 128)  0           inception_3b_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 12, 12, 64)   0           inception_3b_5x5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_10 (ZeroPadding2 (None, 12, 12, 64)   0           activation_14[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 12, 12, 64)   0           inception_3b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 12, 12, 320)  0           activation_11[0][0]
#                                                                  activation_13[0][0]
#                                                                  zero_padding2d_10[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# inception_3c_3x3_conv1 (Conv2D) (None, 12, 12, 128)  41088       concatenate_2[0][0]
# __________________________________________________________________________________________________
# inception_3c_5x5_conv1 (Conv2D) (None, 12, 12, 32)   10272       concatenate_2[0][0]
# __________________________________________________________________________________________________
# inception_3c_3x3_bn1 (BatchNorm (None, 12, 12, 128)  512         inception_3c_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# inception_3c_5x5_bn1 (BatchNorm (None, 12, 12, 32)   128         inception_3c_5x5_conv1[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 12, 12, 128)  0           inception_3c_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 12, 12, 32)   0           inception_3c_5x5_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_11 (ZeroPadding2 (None, 14, 14, 128)  0           activation_16[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_12 (ZeroPadding2 (None, 16, 16, 32)   0           activation_18[0][0]
# __________________________________________________________________________________________________
# inception_3c_3x3_conv2 (Conv2D) (None, 6, 6, 256)    295168      zero_padding2d_11[0][0]
# __________________________________________________________________________________________________
# inception_3c_5x5_conv2 (Conv2D) (None, 6, 6, 64)     51264       zero_padding2d_12[0][0]
# __________________________________________________________________________________________________
# inception_3c_3x3_bn2 (BatchNorm (None, 6, 6, 256)    1024        inception_3c_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# inception_3c_5x5_bn2 (BatchNorm (None, 6, 6, 64)     256         inception_3c_5x5_conv2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 5, 5, 320)    0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 6, 6, 256)    0           inception_3c_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 6, 6, 64)     0           inception_3c_5x5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_13 (ZeroPadding2 (None, 6, 6, 320)    0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 6, 6, 640)    0           activation_17[0][0]
#                                                                  activation_19[0][0]
#                                                                  zero_padding2d_13[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_conv1 (Conv2D) (None, 6, 6, 96)     61536       concatenate_3[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_conv1 (Conv2D) (None, 6, 6, 32)     20512       concatenate_3[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_bn1 (BatchNorm (None, 6, 6, 96)     384         inception_4a_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_bn1 (BatchNorm (None, 6, 6, 32)     128         inception_4a_5x5_conv1[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 6, 6, 96)     0           inception_4a_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 6, 6, 32)     0           inception_4a_5x5_bn1[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 2, 2, 640)    0           concatenate_3[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_14 (ZeroPadding2 (None, 8, 8, 96)     0           activation_20[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_15 (ZeroPadding2 (None, 10, 10, 32)   0           activation_22[0][0]
# __________________________________________________________________________________________________
# inception_4a_pool_conv (Conv2D) (None, 2, 2, 128)    82048       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_conv2 (Conv2D) (None, 6, 6, 192)    166080      zero_padding2d_14[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_conv2 (Conv2D) (None, 6, 6, 64)     51264       zero_padding2d_15[0][0]
# __________________________________________________________________________________________________
# inception_4a_pool_bn (BatchNorm (None, 2, 2, 128)    512         inception_4a_pool_conv[0][0]
# __________________________________________________________________________________________________
# inception_4a_1x1_conv (Conv2D)  (None, 6, 6, 256)    164096      concatenate_3[0][0]
# __________________________________________________________________________________________________
# inception_4a_3x3_bn2 (BatchNorm (None, 6, 6, 192)    768         inception_4a_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# inception_4a_5x5_bn2 (BatchNorm (None, 6, 6, 64)     256         inception_4a_5x5_conv2[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 2, 2, 128)    0           inception_4a_pool_bn[0][0]
# __________________________________________________________________________________________________
# inception_4a_1x1_bn (BatchNorma (None, 6, 6, 256)    1024        inception_4a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 6, 6, 192)    0           inception_4a_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 6, 6, 64)     0           inception_4a_5x5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_16 (ZeroPadding2 (None, 6, 6, 128)    0           activation_24[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 6, 6, 256)    0           inception_4a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 6, 6, 640)    0           activation_21[0][0]
#                                                                  activation_23[0][0]
#                                                                  zero_padding2d_16[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_conv1 (Conv2D) (None, 6, 6, 160)    102560      concatenate_4[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_conv1 (Conv2D) (None, 6, 6, 64)     41024       concatenate_4[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_bn1 (BatchNorm (None, 6, 6, 160)    640         inception_4e_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_bn1 (BatchNorm (None, 6, 6, 64)     256         inception_4e_5x5_conv1[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 6, 6, 160)    0           inception_4e_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 6, 6, 64)     0           inception_4e_5x5_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_17 (ZeroPadding2 (None, 8, 8, 160)    0           activation_26[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_18 (ZeroPadding2 (None, 10, 10, 64)   0           activation_28[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_conv2 (Conv2D) (None, 3, 3, 256)    368896      zero_padding2d_17[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_conv2 (Conv2D) (None, 3, 3, 128)    204928      zero_padding2d_18[0][0]
# __________________________________________________________________________________________________
# inception_4e_3x3_bn2 (BatchNorm (None, 3, 3, 256)    1024        inception_4e_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# inception_4e_5x5_bn2 (BatchNorm (None, 3, 3, 128)    512         inception_4e_5x5_conv2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 2, 2, 640)    0           concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 3, 3, 256)    0           inception_4e_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 3, 3, 128)    0           inception_4e_5x5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_19 (ZeroPadding2 (None, 3, 3, 640)    0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 3, 3, 1024)   0           activation_27[0][0]
#                                                                  activation_29[0][0]
#                                                                  zero_padding2d_19[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_conv1 (Conv2D) (None, 3, 3, 96)     98400       concatenate_5[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_bn1 (BatchNorm (None, 3, 3, 96)     384         inception_5a_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 3, 3, 96)     0           inception_5a_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 1, 1, 1024)   0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_20 (ZeroPadding2 (None, 5, 5, 96)     0           activation_30[0][0]
# __________________________________________________________________________________________________
# inception_5a_pool_conv (Conv2D) (None, 1, 1, 96)     98400       average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_conv2 (Conv2D) (None, 3, 3, 384)    332160      zero_padding2d_20[0][0]
# __________________________________________________________________________________________________
# inception_5a_pool_bn (BatchNorm (None, 1, 1, 96)     384         inception_5a_pool_conv[0][0]
# __________________________________________________________________________________________________
# inception_5a_1x1_conv (Conv2D)  (None, 3, 3, 256)    262400      concatenate_5[0][0]
# __________________________________________________________________________________________________
# inception_5a_3x3_bn2 (BatchNorm (None, 3, 3, 384)    1536        inception_5a_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 1, 1, 96)     0           inception_5a_pool_bn[0][0]
# __________________________________________________________________________________________________
# inception_5a_1x1_bn (BatchNorma (None, 3, 3, 256)    1024        inception_5a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 3, 3, 384)    0           inception_5a_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_21 (ZeroPadding2 (None, 3, 3, 96)     0           activation_32[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 3, 3, 256)    0           inception_5a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 3, 3, 736)    0           activation_31[0][0]
#                                                                  zero_padding2d_21[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_conv1 (Conv2D) (None, 3, 3, 96)     70752       concatenate_6[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_bn1 (BatchNorm (None, 3, 3, 96)     384         inception_5b_3x3_conv1[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 3, 3, 96)     0           inception_5b_3x3_bn1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 1, 1, 736)    0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_22 (ZeroPadding2 (None, 5, 5, 96)     0           activation_34[0][0]
# __________________________________________________________________________________________________
# inception_5b_pool_conv (Conv2D) (None, 1, 1, 96)     70752       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_conv2 (Conv2D) (None, 3, 3, 384)    332160      zero_padding2d_22[0][0]
# __________________________________________________________________________________________________
# inception_5b_pool_bn (BatchNorm (None, 1, 1, 96)     384         inception_5b_pool_conv[0][0]
# __________________________________________________________________________________________________
# inception_5b_1x1_conv (Conv2D)  (None, 3, 3, 256)    188672      concatenate_6[0][0]
# __________________________________________________________________________________________________
# inception_5b_3x3_bn2 (BatchNorm (None, 3, 3, 384)    1536        inception_5b_3x3_conv2[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 1, 1, 96)     0           inception_5b_pool_bn[0][0]
# __________________________________________________________________________________________________
# inception_5b_1x1_bn (BatchNorma (None, 3, 3, 256)    1024        inception_5b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 3, 3, 384)    0           inception_5b_3x3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_23 (ZeroPadding2 (None, 3, 3, 96)     0           activation_36[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 3, 3, 256)    0           inception_5b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 3, 3, 736)    0           activation_35[0][0]
#                                                                  zero_padding2d_23[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_4 (AveragePoo (None, 1, 1, 736)    0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 736)          0           average_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# dense_layer (Dense)             (None, 128)          94336       flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 4)            516         dense_layer[0][0]
# ==================================================================================================
# Total params: 3,743,796
# Trainable params: 3,734,484
# Non-trainable params: 9,312
# __________________________________________________________________________________________________
# None
# No. of hidden layers after addition of extra layers= 157

# %% [markdown]
# ### Run SPLITFOLDERS once

# %%
# import splitfolders

# # To only split into training and validation set, set a tuple to `ratio`, i.e, `(.8, .2)`.
# splitfolders.ratio("./images/", output="./split_small_dataset", seed=1337, ratio=(.6, .2, .2), group_prefix=None)
# Out:
# Copying files: 164 files [00:01, 110.58 files/s]

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)

train_data_dir = "../datasets/split_small_dataset/train/"
val_data_dir = "../datasets/split_small_dataset/val/"
test_data_dir = "../datasets/split_small_dataset/test/"


train_datagen = ImageDataGenerator(rescale = 1./255,
                shear_range = 0.2,
                zoom_range = 0.2,
                horizontal_flip = True)
test_datagen = ImageDataGenerator(rescale = 1./255)
training_set = train_datagen.flow_from_directory(train_data_dir,
                                                 target_size = (img_rows, img_cols),
                                                 batch_size = batch_size,
                                                 class_mode = 'categorical')
val_set = test_datagen.flow_from_directory(val_data_dir,
                                            target_size = (img_rows, img_cols),
                                            batch_size = batch_size,
                                            class_mode = 'categorical')
test_set = test_datagen.flow_from_directory(test_data_dir,
                                            target_size = (img_rows, img_cols),
                                            batch_size = batch_size,
                                            class_mode = 'categorical')
# Out:
# Found 96 images belonging to 4 classes.
# Found 32 images belonging to 4 classes.
# Found 36 images belonging to 4 classes.

# %%
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
                   
checkpoint = ModelCheckpoint("./saved/small_dataset_openface.h5",
                             monitor="val_loss",
                             mode="min",
                             save_best_only = True,
                             verbose=1)

earlystop = EarlyStopping(monitor = 'val_loss', 
                          min_delta = 0, 
                          patience = 5,
                          verbose = 1,
                          restore_best_weights = True)


# we put our call backs into a callback list
callbacks = [earlystop, checkpoint]

# we use a small learning rate 
conv_base.compile(optimizer=RMSprop(lr=2e-5), loss='categorical_crossentropy', metrics=['accuracy','mse','mae','cosine'])


history = conv_base.fit_generator(
    training_set,
    # set steps per epoch equal to the number of training images
    steps_per_epoch = 96,
    epochs = epochs,
    callbacks = callbacks,
    validation_data = val_set,
    validation_steps = 100)

conv_base.save("./saved/small_dataset_openface.h5")
# Out:
# Epoch 1/300
# 96/96 [==============================] - 217s 2s/step - loss: 0.8514 - acc: 0.8053 - mean_squared_error: 0.1420 - mean_absolute_error: 0.3205 - cosine_proximity: -0.7477 - val_loss: 0.4977 - val_acc: 0.7812 - val_mean_squared_error: 0.0653 - val_mean_absolute_error: 0.1734 - val_cosine_proximity: -0.8581
#
# Epoch 00001: val_loss improved from inf to 0.49768, saving model to ./saved/small_dataset_openface.h5
# Epoch 2/300
# 96/96 [==============================] - 213s 2s/step - loss: 0.1718 - acc: 0.9831 - mean_squared_error: 0.0214 - mean_absolute_error: 0.0828 - cosine_proximity: -0.9754 - val_loss: 0.1459 - val_acc: 0.9688 - val_mean_squared_error: 0.0381 - val_mean_absolute_error: 0.0901 - val_cosine_proximity: -0.9731
#
# Epoch 00002: val_loss improved from 0.49768 to 0.14589, saving model to ./saved/small_dataset_openface.h5
# Epoch 3/300
# 96/96 [==============================] - 216s 2s/step - loss: 0.0464 - acc: 0.9954 - mean_squared_error: 0.0182 - mean_absolute_error: 0.0539 - cosine_proximity: -0.9947 - val_loss: 0.1498 - val_acc: 0.9375 - val_mean_squared_error: 0.0425 - val_mean_absolute_error: 0.0773 - val_cosine_proximity: -0.9511
#
# Epoch 00003: val_loss did not improve from 0.14589
# Epoch 4/300
# 96/96 [==============================] - 220s 2s/step - loss: 0.0132 - acc: 0.9993 - mean_squared_error: 0.0153 - mean_absolute_error: 0.0456 - cosine_proximity: -0.9990 - val_loss: 0.0122 - val_acc: 1.0000 - val_mean_squared_error: 0.0252 - val_mean_absolute_error: 0.0623 - val_cosine_proximity: -0.9997
#
# Epoch 00004: val_loss improved from 0.14589 to 0.01221, saving model to ./saved/small_dataset_openface.h5
# Epoch 5/300
# 96/96 [==============================] - 217s 2s/step - loss: 0.0060 - acc: 1.0000 - mean_squared_error: 0.0164 - mean_absolute_error: 0.0443 - cosine_proximity: -0.9996 - val_loss: 0.0052 - val_acc: 1.0000 - val_mean_squared_error: 0.0210 - val_mean_absolute_error: 0.0537 - val_cosine_proximity: -1.0000
#
# Epoch 00005: val_loss improved from 0.01221 to 0.00522, saving model to ./saved/small_dataset_openface.h5
# Epoch 6/300
# 96/96 [==============================] - 219s 2s/step - loss: 0.0034 - acc: 1.0000 - mean_squared_error: 0.0155 - mean_absolute_error: 0.0413 - cosine_proximity: -0.9997 - val_loss: 0.0045 - val_acc: 1.0000 - val_mean_squared_error: 0.0226 - val_mean_absolute_error: 0.0505 - val_cosine_proximity: -0.9999
#
# Epoch 00006: val_loss improved from 0.00522 to 0.00451, saving model to ./saved/small_dataset_openface.h5
# Epoch 7/300
# 96/96 [==============================] - 219s 2s/step - loss: 0.0025 - acc: 1.0000 - mean_squared_error: 0.0188 - mean_absolute_error: 0.0451 - cosine_proximity: -0.9999 - val_loss: 0.0118 - val_acc: 1.0000 - val_mean_squared_error: 0.0372 - val_mean_absolute_error: 0.0706 - val_cosine_proximity: -0.9985
#
# Epoch 00007: val_loss did not improve from 0.00451
# Epoch 8/300
# 96/96 [==============================] - 220s 2s/step - loss: 0.0011 - acc: 1.0000 - mean_squared_error: 0.0149 - mean_absolute_error: 0.0391 - cosine_proximity: -1.0000 - val_loss: 0.0017 - val_acc: 1.0000 - val_mean_squared_error: 0.0247 - val_mean_absolute_error: 0.0549 - val_cosine_proximity: -1.0000
#
# Epoch 00008: val_loss improved from 0.00451 to 0.00174, saving model to ./saved/small_dataset_openface.h5
# Epoch 9/300
# 96/96 [==============================] - 220s 2s/step - loss: 0.0033 - acc: 0.9987 - mean_squared_error: 0.0150 - mean_absolute_error: 0.0377 - cosine_proximity: -0.9991 - val_loss: 0.0653 - val_acc: 0.9688 - val_mean_squared_error: 0.0358 - val_mean_absolute_error: 0.0631 - val_cosine_proximity: -0.9736
#
# Epoch 00009: val_loss did not improve from 0.00174
# Epoch 10/300
# 96/96 [==============================] - 219s 2s/step - loss: 0.0035 - acc: 0.9987 - mean_squared_error: 0.0175 - mean_absolute_error: 0.0408 - cosine_proximity: -0.9989 - val_loss: 0.0017 - val_acc: 1.0000 - val_mean_squared_error: 0.0220 - val_mean_absolute_error: 0.0487 - val_cosine_proximity: -1.0000
#
# Epoch 00010: val_loss improved from 0.00174 to 0.00167, saving model to ./saved/small_dataset_openface.h5
# Epoch 11/300
# 96/96 [==============================] - 216s 2s/step - loss: 6.7629e-04 - acc: 1.0000 - mean_squared_error: 0.0161 - mean_absolute_error: 0.0403 - cosine_proximity: -1.0000 - val_loss: 0.0194 - val_acc: 1.0000 - val_mean_squared_error: 0.0290 - val_mean_absolute_error: 0.0523 - val_cosine_proximity: -0.9945
#
# Epoch 00011: val_loss did not improve from 0.00167
# Epoch 12/300
# 96/96 [==============================] - 217s 2s/step - loss: 8.8359e-04 - acc: 1.0000 - mean_squared_error: 0.0160 - mean_absolute_error: 0.0400 - cosine_proximity: -0.9999 - val_loss: 5.6634e-04 - val_acc: 1.0000 - val_mean_squared_error: 0.0242 - val_mean_absolute_error: 0.0524 - val_cosine_proximity: -1.0000
#
# Epoch 00012: val_loss improved from 0.00167 to 0.00057, saving model to ./saved/small_dataset_openface.h5
# Epoch 13/300
# 96/96 [==============================] - 217s 2s/step - loss: 8.8131e-04 - acc: 1.0000 - mean_squared_error: 0.0170 - mean_absolute_error: 0.0403 - cosine_proximity: -0.9999 - val_loss: 0.0012 - val_acc: 1.0000 - val_mean_squared_error: 0.0251 - val_mean_absolute_error: 0.0556 - val_cosine_proximity: -1.0000
#
# Epoch 00013: val_loss did not improve from 0.00057
# Epoch 14/300
# 96/96 [==============================] - 220s 2s/step - loss: 6.7487e-04 - acc: 1.0000 - mean_squared_error: 0.0165 - mean_absolute_error: 0.0393 - cosine_proximity: -0.9999 - val_loss: 3.8533e-04 - val_acc: 1.0000 - val_mean_squared_error: 0.0269 - val_mean_absolute_error: 0.0561 - val_cosine_proximity: -1.0000
#
# Epoch 00014: val_loss improved from 0.00057 to 0.00039, saving model to ./saved/small_dataset_openface.h5
# Epoch 15/300
# 96/96 [==============================] - 221s 2s/step - loss: 0.0011 - acc: 0.9993 - mean_squared_error: 0.0135 - mean_absolute_error: 0.0360 - cosine_proximity: -0.9996 - val_loss: 9.5570e-05 - val_acc: 1.0000 - val_mean_squared_error: 0.0149 - val_mean_absolute_error: 0.0460 - val_cosine_proximity: -1.0000
#
# Epoch 00015: val_loss improved from 0.00039 to 0.00010, saving model to ./saved/small_dataset_openface.h5
# Epoch 16/300
# 96/96 [==============================] - 220s 2s/step - loss: 3.4194e-04 - acc: 1.0000 - mean_squared_error: 0.0160 - mean_absolute_error: 0.0381 - cosine_proximity: -1.0000 - val_loss: 5.1466e-04 - val_acc: 1.0000 - val_mean_squared_error: 0.0245 - val_mean_absolute_error: 0.0517 - val_cosine_proximity: -1.0000
#
# Epoch 00016: val_loss did not improve from 0.00010
# Epoch 17/300
# 96/96 [==============================] - 278s 3s/step - loss: 1.0484e-04 - acc: 1.0000 - mean_squared_error: 0.0125 - mean_absolute_error: 0.0334 - cosine_proximity: -1.0000 - val_loss: 2.0217e-04 - val_acc: 1.0000 - val_mean_squared_error: 0.0235 - val_mean_absolute_error: 0.0510 - val_cosine_proximity: -1.0000
#
# Epoch 00017: val_loss did not improve from 0.00010
# Epoch 18/300
# 96/96 [==============================] - 216s 2s/step - loss: 3.2044e-04 - acc: 1.0000 - mean_squared_error: 0.0177 - mean_absolute_error: 0.0396 - cosine_proximity: -1.0000 - val_loss: 7.3178e-05 - val_acc: 1.0000 - val_mean_squared_error: 0.0214 - val_mean_absolute_error: 0.0464 - val_cosine_proximity: -1.0000
#
# Epoch 00018: val_loss improved from 0.00010 to 0.00007, saving model to ./saved/small_dataset_openface.h5
# Epoch 19/300
# 96/96 [==============================] - 216s 2s/step - loss: 0.0031 - acc: 0.9987 - mean_squared_error: 0.0145 - mean_absolute_error: 0.0344 - cosine_proximity: -0.9988 - val_loss: 2.6045e-05 - val_acc: 1.0000 - val_mean_squared_error: 0.0117 - val_mean_absolute_error: 0.0390 - val_cosine_proximity: -1.0000
#
# Epoch 00019: val_loss improved from 0.00007 to 0.00003, saving model to ./saved/small_dataset_openface.h5
# Epoch 20/300
# 96/96 [==============================] - 218s 2s/step - loss: 1.9826e-04 - acc: 1.0000 - mean_squared_error: 0.0132 - mean_absolute_error: 0.0329 - cosine_proximity: -1.0000 - val_loss: 1.0579e-04 - val_acc: 1.0000 - val_mean_squared_error: 0.0149 - val_mean_absolute_error: 0.0386 - val_cosine_proximity: -1.0000
#
# Epoch 00020: val_loss did not improve from 0.00003
# Epoch 21/300
# 96/96 [==============================] - 216s 2s/step - loss: 9.9297e-04 - acc: 0.9993 - mean_squared_error: 0.0134 - mean_absolute_error: 0.0317 - cosine_proximity: -0.9997 - val_loss: 3.9290e-05 - val_acc: 1.0000 - val_mean_squared_error: 0.0123 - val_mean_absolute_error: 0.0361 - val_cosine_proximity: -1.0000
#
# Epoch 00021: val_loss did not improve from 0.00003
# Epoch 22/300
# 96/96 [==============================] - 216s 2s/step - loss: 1.6020e-04 - acc: 1.0000 - mean_squared_error: 0.0152 - mean_absolute_error: 0.0364 - cosine_proximity: -1.0000 - val_loss: 0.0033 - val_acc: 1.0000 - val_mean_squared_error: 0.0376 - val_mean_absolute_error: 0.0544 - val_cosine_proximity: -0.9999
#
# Epoch 00022: val_loss did not improve from 0.00003
# Epoch 23/300
# 96/96 [==============================] - 218s 2s/step - loss: 2.4016e-04 - acc: 1.0000 - mean_squared_error: 0.0107 - mean_absolute_error: 0.0293 - cosine_proximity: -1.0000 - val_loss: 2.0971e-04 - val_acc: 1.0000 - val_mean_squared_error: 0.0177 - val_mean_absolute_error: 0.0403 - val_cosine_proximity: -1.0000
#
# Epoch 00023: val_loss did not improve from 0.00003
# Epoch 24/300
# 96/96 [==============================] - 219s 2s/step - loss: 8.5074e-05 - acc: 1.0000 - mean_squared_error: 0.0127 - mean_absolute_error: 0.0312 - cosine_proximity: -1.0000 - val_loss: 1.8048e-05 - val_acc: 1.0000 - val_mean_squared_error: 0.0174 - val_mean_absolute_error: 0.0386 - val_cosine_proximity: -1.0000
#
# Epoch 00024: val_loss improved from 0.00003 to 0.00002, saving model to ./saved/small_dataset_openface.h5
# Epoch 25/300
# 96/96 [==============================] - 222s 2s/step - loss: 1.7022e-04 - acc: 1.0000 - mean_squared_error: 0.0130 - mean_absolute_error: 0.0318 - cosine_proximity: -1.0000 - val_loss: 7.4080e-05 - val_acc: 1.0000 - val_mean_squared_error: 0.0180 - val_mean_absolute_error: 0.0397 - val_cosine_proximity: -1.0000
#
# Epoch 00025: val_loss did not improve from 0.00002
# Epoch 26/300
# 96/96 [==============================] - 222s 2s/step - loss: 4.2689e-04 - acc: 1.0000 - mean_squared_error: 0.0119 - mean_absolute_error: 0.0298 - cosine_proximity: -0.9999 - val_loss: 7.0481e-05 - val_acc: 1.0000 - val_mean_squared_error: 0.0181 - val_mean_absolute_error: 0.0386 - val_cosine_proximity: -1.0000
#
# Epoch 00026: val_loss did not improve from 0.00002
# Epoch 27/300
# 96/96 [==============================] - 218s 2s/step - loss: 7.1137e-05 - acc: 1.0000 - mean_squared_error: 0.0123 - mean_absolute_error: 0.0306 - cosine_proximity: -1.0000 - val_loss: 1.7325e-05 - val_acc: 1.0000 - val_mean_squared_error: 0.0132 - val_mean_absolute_error: 0.0366 - val_cosine_proximity: -1.0000
#
# Epoch 00027: val_loss improved from 0.00002 to 0.00002, saving model to ./saved/small_dataset_openface.h5
# Epoch 28/300
# 96/96 [==============================] - 218s 2s/step - loss: 1.1380e-04 - acc: 1.0000 - mean_squared_error: 0.0110 - mean_absolute_error: 0.0290 - cosine_proximity: -1.0000 - val_loss: 6.8565e-06 - val_acc: 1.0000 - val_mean_squared_error: 0.0135 - val_mean_absolute_error: 0.0362 - val_cosine_proximity: -1.0000
#
# Epoch 00028: val_loss improved from 0.00002 to 0.00001, saving model to ./saved/small_dataset_openface.h5
# Epoch 29/300
# 96/96 [==============================] - 218s 2s/step - loss: 6.9074e-04 - acc: 1.0000 - mean_squared_error: 0.0141 - mean_absolute_error: 0.0338 - cosine_proximity: -0.9998 - val_loss: 3.5752e-04 - val_acc: 1.0000 - val_mean_squared_error: 0.0134 - val_mean_absolute_error: 0.0355 - val_cosine_proximity: -1.0000
#
# Epoch 00029: val_loss did not improve from 0.00001
# Epoch 30/300
# 96/96 [==============================] - 218s 2s/step - loss: 6.2978e-05 - acc: 1.0000 - mean_squared_error: 0.0156 - mean_absolute_error: 0.0364 - cosine_proximity: -1.0000 - val_loss: 1.0792e-04 - val_acc: 1.0000 - val_mean_squared_error: 0.0211 - val_mean_absolute_error: 0.0424 - val_cosine_proximity: -1.0000
#
# Epoch 00030: val_loss did not improve from 0.00001
# Epoch 31/300
# 96/96 [==============================] - 219s 2s/step - loss: 1.9565e-04 - acc: 1.0000 - mean_squared_error: 0.0132 - mean_absolute_error: 0.0311 - cosine_proximity: -1.0000 - val_loss: 3.1207e-05 - val_acc: 1.0000 - val_mean_squared_error: 0.0150 - val_mean_absolute_error: 0.0334 - val_cosine_proximity: -1.0000
#
# Epoch 00031: val_loss did not improve from 0.00001
# Epoch 32/300
# 96/96 [==============================] - 218s 2s/step - loss: 4.2151e-04 - acc: 1.0000 - mean_squared_error: 0.0122 - mean_absolute_error: 0.0302 - cosine_proximity: -0.9999 - val_loss: 1.0806e-04 - val_acc: 1.0000 - val_mean_squared_error: 0.0230 - val_mean_absolute_error: 0.0419 - val_cosine_proximity: -1.0000
#
# Epoch 00032: val_loss did not improve from 0.00001
# Epoch 33/300
# 96/96 [==============================] - 219s 2s/step - loss: 1.1394e-04 - acc: 1.0000 - mean_squared_error: 0.0144 - mean_absolute_error: 0.0329 - cosine_proximity: -1.0000 - val_loss: 3.2892e-05 - val_acc: 1.0000 - val_mean_squared_error: 0.0214 - val_mean_absolute_error: 0.0399 - val_cosine_proximity: -1.0000
# Restoring model weights from the end of the best epoch
#
# Epoch 00033: val_loss did not improve from 0.00001
# Epoch 00033: early stopping

# %% [markdown]
# ### Plot

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.DataFrame(history.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0,1)
plt.show()

# %%
plt.figure(figsize=(16,5))
plt.subplot(121)
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')
plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')

plt.show()

# %%
plt.figure(figsize=(16,5))
plt.subplot(121)
plt.plot(history.history['val_cosine_proximity'])
plt.plot(history.history['cosine_proximity'])
plt.title('Cosine Similarity')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')
plt.subplot(122)
plt.plot(history.history['val_mean_absolute_error'])
plt.plot(history.history['mean_absolute_error'])
plt.title('Mean Absolute Error')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')

plt.show()

# %%
plt.figure(figsize=(16,5))
plt.subplot(121)
plt.plot(history.history['val_mean_squared_error'])
plt.plot(history.history['mean_squared_error'])
plt.title('Mean Squared Error')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')

# %%
conv_base.evaluate_generator(test_set, steps=50)
# Out:
# [0.0016106158540394905,
#  1.0,
#  0.017086943240237337,
#  0.03751282394238699,
#  -0.9999562141142393]
