# %%
from keras.applications import VGG16
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, GlobalAveragePooling2D
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D
from keras.layers.normalization import BatchNormalization
from keras.models import Model
from tensorflow.keras import models
from tensorflow.keras import layers
from keras.optimizers import RMSprop, Adam, adam
from keras.preprocessing.image import ImageDataGenerator
# Out:
# Using TensorFlow backend.
# C:\Users\omool\anaconda3\envs\Computer_Vision_python_3_6\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\omool\anaconda3\envs\Computer_Vision_python_3_6\lib\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\omool\anaconda3\envs\Computer_Vision_python_3_6\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\omool\anaconda3\envs\Computer_Vision_python_3_6\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\omool\anaconda3\envs\Computer_Vision_python_3_6\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\omool\anaconda3\envs\Computer_Vision_python_3_6\lib\site-packages\tensorflow\python\framework\dtypes.py:532: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def FindBatchSize(model):
    """model: model architecture, that is yet to be trained"""
    import os, sys, psutil, gc, tensorflow, keras
    import numpy as np
    from keras import backend as K
    BatchFound= 16

    try:
        total_params= int(model.count_params());    GCPU= "CPU"
        #find whether gpu is available
        try:
            if K.tensorflow_backend._get_available_gpus()== []:
                GCPU= "CPU";    #CPU and Cuda9GPU
            else:
                GCPU= "GPU"
        except:
            from tensorflow.python.client import device_lib;    #Cuda8GPU
            def get_available_gpus():
                local_device_protos= device_lib.list_local_devices()
                return [x.name for x in local_device_protos if x.device_type == 'GPU']
            if "gpu" not in str(get_available_gpus()).lower():
                GCPU= "CPU"
            else:
                GCPU= "GPU"

        #decide batch size on the basis of GPU availability and model complexity
        if (GCPU== "GPU") and (os.cpu_count() >15) and (total_params <1000000):
            BatchFound= 64    
        if (os.cpu_count() <16) and (total_params <500000):
            BatchFound= 64  
        if (GCPU== "GPU") and (os.cpu_count() >15) and (total_params <2000000) and (total_params >=1000000):
            BatchFound= 32      
        if (GCPU== "GPU") and (os.cpu_count() >15) and (total_params >=2000000) and (total_params <10000000):
            BatchFound= 16  
        if (GCPU== "GPU") and (os.cpu_count() >15) and (total_params >=10000000):
            BatchFound= 8       
        if (os.cpu_count() <16) and (total_params >5000000):
            BatchFound= 8    
        if total_params >100000000:
            BatchFound= 1

    except:
        pass
    try:

        #find percentage of memory used
        memoryused= psutil.virtual_memory()
        memoryused= float(str(memoryused).replace(" ", "").split("percent=")[1].split(",")[0])
        if memoryused >75.0:
            BatchFound= 8
        if memoryused >85.0:
            BatchFound= 4
        if memoryused >90.0:
            BatchFound= 2
        if total_params >100000000:
            BatchFound= 1
        print("Batch Size:  "+ str(BatchFound));    gc.collect()
    except:
        pass

    memoryused= [];    total_params= [];    GCPU= "";
    del memoryused, total_params, GCPU;    gc.collect()
    return BatchFound

# %%
img_rows = 220
img_cols = 220 

# Change the batchsize according to your system RAM
train_batchsize = 16
num_classes = 4
nb_train_samples = 132
nb_validation_samples = 32
epochs = 300
batch_size = 16

# %%
########Data Splitting #######

train_data_dir = './images'

validation_datagen = ImageDataGenerator(rescale=1./255)

datagen = ImageDataGenerator(
          rescale=1./255,
          rotation_range=30,
          shear_range=0.3,
          zoom_range=0.3,
          width_shift_range=0.4,
          height_shift_range=0.4,
          horizontal_flip=True,
          fill_mode='nearest',
          validation_split=0.2)

train_generator = datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_rows, img_cols),
        batch_size=train_batchsize,
        class_mode='categorical',
        shuffle=True,
        subset='training')

test_datagen = ImageDataGenerator(rescale=1./255)

validation_generator = datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_rows, img_cols),
        batch_size=train_batchsize,
        class_mode='categorical',
        shuffle=True, 
        subset='validation')
# Out:
# Found 132 images belonging to 4 classes.
# Found 32 images belonging to 4 classes.

# %% [markdown]
# # Training our Custom VGG16 Model Using Transfer Learning
#
# ### Loading the VGG16 Model

# %%
#Loads the VGG16 model 
base_conv = VGG16(weights = 'imagenet', 
                 include_top = False, 
                 input_shape = (img_rows, img_cols, 3))

# %%
# Print our layers 
for (i,layer) in enumerate(base_conv.layers):
    print(str(i) + " "+ layer.__class__.__name__, layer.trainable)
# Out:
# 0 InputLayer False
# 1 Conv2D True
# 2 Conv2D True
# 3 MaxPooling2D True
# 4 Conv2D True
# 5 Conv2D True
# 6 MaxPooling2D True
# 7 Conv2D True
# 8 Conv2D True
# 9 Conv2D True
# 10 MaxPooling2D True
# 11 Conv2D True
# 12 Conv2D True
# 13 Conv2D True
# 14 MaxPooling2D True
# 15 Conv2D True
# 16 Conv2D True
# 17 Conv2D True
# 18 MaxPooling2D True

# %% [markdown]
# ### Inpsecting each layer

# %%
base_conv.summary()
print('No. of hidden layers without extra class number= {}'.format(len(base_conv.layers)))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 220, 220, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 220, 220, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 220, 220, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 110, 110, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 110, 110, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 110, 110, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 55, 55, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 55, 55, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 55, 55, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 55, 55, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 27, 27, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 27, 27, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 27, 27, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 27, 27, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 13, 13, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 13, 13, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 13, 13, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 13, 13, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 6, 6, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________
# No. of hidden layers without extra class number= 19

# %% [markdown]
# ### Makes a function that returns our TL head

# %%
def addTopModel(bottom_model, num_classes, D=256):
    """creates the top or head of the model that will be 
    placed ontop of the bottom layers"""
    top_model = bottom_model.output
    top_model = Flatten(name = "flatten")(top_model)
    top_model = Dense(D, activation = "relu")(top_model)
    top_model = Dense(num_classes, activation = "sigmoid")(top_model)
    return top_model

# %% [markdown]
# ### Let's add our TL Head back onto VGG

# %%
FC_Head = addTopModel(base_conv, num_classes)

model = Model(inputs=base_conv.input, outputs=FC_Head)

print(model.summary())
print('No. of hidden layers after addition of extra layers = {}'.format(len(model.layers)))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 220, 220, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 220, 220, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 220, 220, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 110, 110, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 110, 110, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 110, 110, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 55, 55, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 55, 55, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 55, 55, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 55, 55, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 27, 27, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 27, 27, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 27, 27, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 27, 27, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 13, 13, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 13, 13, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 13, 13, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 13, 13, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 6, 6, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18432)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               4718848
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 1028
# =================================================================
# Total params: 19,434,564
# Trainable params: 19,434,564
# Non-trainable params: 0
# _________________________________________________________________
# None
# No. of hidden layers after addition of extra layers = 22

# %%
FindBatchSize(model)

# %% [markdown]
# ### Trainning Begins

# %%
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
                   
checkpoint = ModelCheckpoint("./saved_trained_model/vgg/small_dataset_vgg.h5",
                             monitor="val_loss",
                             mode="min",
                             save_best_only = True,
                             verbose=1)

earlystop = EarlyStopping(monitor = 'val_loss', 
                          min_delta = 0, 
                          patience = 5,
                          verbose = 1,
                          restore_best_weights = True)


# we put our call backs into a callback list
callbacks = [earlystop, checkpoint]

# we use a small learning rate 
model.compile(optimizer=RMSprop(lr=2e-5), loss='categorical_crossentropy', metrics=['accuracy','mse','mae','cosine'])


history = model.fit_generator(
    train_generator,
    steps_per_epoch = nb_train_samples // batch_size,
    epochs = epochs,
    callbacks = callbacks,
    validation_data = validation_generator,
    validation_steps = nb_validation_samples // batch_size)

model.save("./saved_trained_model/vgg/small_dataset_vgg.h5")
# Out:
# Epoch 1/300
# 8/8 [==============================] - 252s 32s/step - loss: 1.3650 - acc: 0.2969 - mean_squared_error: 0.2771 - mean_absolute_error: 0.5049 - cosine_proximity: -0.5107 - val_loss: 1.2828 - val_acc: 0.5625 - val_mean_squared_error: 0.2601 - val_mean_absolute_error: 0.4864 - val_cosine_proximity: -0.5592
#
# Epoch 00001: val_loss improved from inf to 1.28283, saving model to ./saved_trained_model/vgg/small_dataset_vgg.h5
# Epoch 2/300
# 8/8 [==============================] - 215s 27s/step - loss: 1.2978 - acc: 0.3556 - mean_squared_error: 0.2675 - mean_absolute_error: 0.4901 - cosine_proximity: -0.5424 - val_loss: 0.9997 - val_acc: 0.7188 - val_mean_squared_error: 0.1494 - val_mean_absolute_error: 0.3542 - val_cosine_proximity: -0.6855
#
# Epoch 00002: val_loss improved from 1.28283 to 0.99965, saving model to ./saved_trained_model/vgg/small_dataset_vgg.h5
# Epoch 3/300
# 8/8 [==============================] - 215s 27s/step - loss: 1.2221 - acc: 0.4813 - mean_squared_error: 0.1818 - mean_absolute_error: 0.3737 - cosine_proximity: -0.5882 - val_loss: 1.0875 - val_acc: 0.5938 - val_mean_squared_error: 0.1482 - val_mean_absolute_error: 0.3253 - val_cosine_proximity: -0.6435
#
# Epoch 00003: val_loss did not improve from 0.99965
# Epoch 4/300
# 8/8 [==============================] - 219s 27s/step - loss: 0.8746 - acc: 0.6868 - mean_squared_error: 0.1258 - mean_absolute_error: 0.2720 - cosine_proximity: -0.7209 - val_loss: 0.4801 - val_acc: 0.9062 - val_mean_squared_error: 0.1144 - val_mean_absolute_error: 0.2001 - val_cosine_proximity: -0.8688
#
# Epoch 00004: val_loss improved from 0.99965 to 0.48009, saving model to ./saved_trained_model/vgg/small_dataset_vgg.h5
# Epoch 5/300
# 8/8 [==============================] - 219s 27s/step - loss: 0.8717 - acc: 0.6789 - mean_squared_error: 0.1248 - mean_absolute_error: 0.2287 - cosine_proximity: -0.7186 - val_loss: 0.4456 - val_acc: 0.7812 - val_mean_squared_error: 0.0819 - val_mean_absolute_error: 0.1652 - val_cosine_proximity: -0.8550
#
# Epoch 00005: val_loss improved from 0.48009 to 0.44555, saving model to ./saved_trained_model/vgg/small_dataset_vgg.h5
# Epoch 6/300
# 8/8 [==============================] - 232s 29s/step - loss: 0.5794 - acc: 0.8111 - mean_squared_error: 0.1071 - mean_absolute_error: 0.1898 - cosine_proximity: -0.8205 - val_loss: 0.3922 - val_acc: 0.9062 - val_mean_squared_error: 0.0904 - val_mean_absolute_error: 0.1600 - val_cosine_proximity: -0.8942
#
# Epoch 00006: val_loss improved from 0.44555 to 0.39216, saving model to ./saved_trained_model/vgg/small_dataset_vgg.h5
# Epoch 7/300
# 8/8 [==============================] - 233s 29s/step - loss: 0.5031 - acc: 0.7687 - mean_squared_error: 0.1157 - mean_absolute_error: 0.1715 - cosine_proximity: -0.8264 - val_loss: 0.4859 - val_acc: 0.8750 - val_mean_squared_error: 0.1002 - val_mean_absolute_error: 0.1761 - val_cosine_proximity: -0.8646
#
# Epoch 00007: val_loss did not improve from 0.39216
# Epoch 8/300
# 8/8 [==============================] - 228s 28s/step - loss: 0.4824 - acc: 0.8527 - mean_squared_error: 0.0960 - mean_absolute_error: 0.1558 - cosine_proximity: -0.8518 - val_loss: 0.3805 - val_acc: 0.8125 - val_mean_squared_error: 0.0852 - val_mean_absolute_error: 0.1526 - val_cosine_proximity: -0.8779
#
# Epoch 00008: val_loss improved from 0.39216 to 0.38054, saving model to ./saved_trained_model/vgg/small_dataset_vgg.h5
# Epoch 9/300
# 8/8 [==============================] - 220s 28s/step - loss: 0.3155 - acc: 0.8922 - mean_squared_error: 0.0910 - mean_absolute_error: 0.1493 - cosine_proximity: -0.9074 - val_loss: 0.2060 - val_acc: 0.9062 - val_mean_squared_error: 0.0955 - val_mean_absolute_error: 0.1437 - val_cosine_proximity: -0.9334
#
# Epoch 00009: val_loss improved from 0.38054 to 0.20599, saving model to ./saved_trained_model/vgg/small_dataset_vgg.h5
# Epoch 10/300
# 8/8 [==============================] - 240s 30s/step - loss: 0.2167 - acc: 0.9453 - mean_squared_error: 0.1036 - mean_absolute_error: 0.1464 - cosine_proximity: -0.9429 - val_loss: 0.4182 - val_acc: 0.8438 - val_mean_squared_error: 0.1182 - val_mean_absolute_error: 0.1527 - val_cosine_proximity: -0.8679
#
# Epoch 00010: val_loss did not improve from 0.20599
# Epoch 11/300
# 8/8 [==============================] - 236s 29s/step - loss: 0.1279 - acc: 0.9605 - mean_squared_error: 0.1073 - mean_absolute_error: 0.1440 - cosine_proximity: -0.9657 - val_loss: 2.6968 - val_acc: 0.4688 - val_mean_squared_error: 0.2094 - val_mean_absolute_error: 0.2464 - val_cosine_proximity: -0.5022
#
# Epoch 00011: val_loss did not improve from 0.20599
# Epoch 12/300
# 8/8 [==============================] - 257s 32s/step - loss: 0.3926 - acc: 0.8736 - mean_squared_error: 0.0911 - mean_absolute_error: 0.1332 - cosine_proximity: -0.8869 - val_loss: 0.1751 - val_acc: 0.9062 - val_mean_squared_error: 0.1029 - val_mean_absolute_error: 0.1379 - val_cosine_proximity: -0.9366
#
# Epoch 00012: val_loss improved from 0.20599 to 0.17509, saving model to ./saved_trained_model/vgg/small_dataset_vgg.h5
# Epoch 13/300
# 8/8 [==============================] - 290s 36s/step - loss: 0.7499 - acc: 0.7629 - mean_squared_error: 0.1230 - mean_absolute_error: 0.1741 - cosine_proximity: -0.8012 - val_loss: 0.2160 - val_acc: 0.9375 - val_mean_squared_error: 0.0427 - val_mean_absolute_error: 0.0988 - val_cosine_proximity: -0.9495
#
# Epoch 00013: val_loss did not improve from 0.17509
# Epoch 14/300
# 8/8 [==============================] - 262s 33s/step - loss: 0.1426 - acc: 0.9526 - mean_squared_error: 0.0434 - mean_absolute_error: 0.0901 - cosine_proximity: -0.9629 - val_loss: 0.1108 - val_acc: 0.9688 - val_mean_squared_error: 0.0421 - val_mean_absolute_error: 0.0817 - val_cosine_proximity: -0.9702
#
# Epoch 00014: val_loss improved from 0.17509 to 0.11076, saving model to ./saved_trained_model/vgg/small_dataset_vgg.h5
# Epoch 15/300
# 8/8 [==============================] - 228s 28s/step - loss: 0.1236 - acc: 0.9605 - mean_squared_error: 0.0511 - mean_absolute_error: 0.0887 - cosine_proximity: -0.9659 - val_loss: 0.3066 - val_acc: 0.8750 - val_mean_squared_error: 0.0696 - val_mean_absolute_error: 0.1014 - val_cosine_proximity: -0.9001
#
# Epoch 00015: val_loss did not improve from 0.11076
# Epoch 16/300
# 8/8 [==============================] - 230s 29s/step - loss: 0.5842 - acc: 0.7895 - mean_squared_error: 0.0847 - mean_absolute_error: 0.1316 - cosine_proximity: -0.8506 - val_loss: 0.1970 - val_acc: 0.9375 - val_mean_squared_error: 0.0520 - val_mean_absolute_error: 0.0913 - val_cosine_proximity: -0.9363
#
# Epoch 00016: val_loss did not improve from 0.11076
# Epoch 17/300
# 8/8 [==============================] - 236s 30s/step - loss: 0.1310 - acc: 0.9684 - mean_squared_error: 0.0352 - mean_absolute_error: 0.0700 - cosine_proximity: -0.9631 - val_loss: 0.0473 - val_acc: 1.0000 - val_mean_squared_error: 0.0580 - val_mean_absolute_error: 0.0863 - val_cosine_proximity: -0.9955
#
# Epoch 00017: val_loss improved from 0.11076 to 0.04735, saving model to ./saved_trained_model/vgg/small_dataset_vgg.h5
# Epoch 18/300
# 8/8 [==============================] - 230s 29s/step - loss: 0.0673 - acc: 0.9921 - mean_squared_error: 0.0665 - mean_absolute_error: 0.0949 - cosine_proximity: -0.9841 - val_loss: 0.0691 - val_acc: 0.9688 - val_mean_squared_error: 0.0497 - val_mean_absolute_error: 0.0780 - val_cosine_proximity: -0.9722
#
# Epoch 00018: val_loss did not improve from 0.04735
# Epoch 19/300
# 8/8 [==============================] - 257s 32s/step - loss: 0.0770 - acc: 0.9766 - mean_squared_error: 0.0567 - mean_absolute_error: 0.0838 - cosine_proximity: -0.9803 - val_loss: 0.0678 - val_acc: 1.0000 - val_mean_squared_error: 0.0806 - val_mean_absolute_error: 0.0994 - val_cosine_proximity: -0.9827
#
# Epoch 00019: val_loss did not improve from 0.04735
# Epoch 20/300
# 8/8 [==============================] - 237s 30s/step - loss: 0.7457 - acc: 0.8815 - mean_squared_error: 0.0869 - mean_absolute_error: 0.1170 - cosine_proximity: -0.8900 - val_loss: 0.0791 - val_acc: 0.9688 - val_mean_squared_error: 0.0404 - val_mean_absolute_error: 0.0809 - val_cosine_proximity: -0.9804
#
# Epoch 00020: val_loss did not improve from 0.04735
# Epoch 21/300
# 8/8 [==============================] - 248s 31s/step - loss: 0.1042 - acc: 0.9763 - mean_squared_error: 0.0455 - mean_absolute_error: 0.0772 - cosine_proximity: -0.9777 - val_loss: 0.0636 - val_acc: 0.9688 - val_mean_squared_error: 0.0266 - val_mean_absolute_error: 0.0509 - val_cosine_proximity: -0.9802
#
# Epoch 00021: val_loss did not improve from 0.04735
# Epoch 22/300
# 8/8 [==============================] - 284s 35s/step - loss: 0.1042 - acc: 0.9605 - mean_squared_error: 0.0288 - mean_absolute_error: 0.0525 - cosine_proximity: -0.9678 - val_loss: 0.2421 - val_acc: 0.9375 - val_mean_squared_error: 0.0391 - val_mean_absolute_error: 0.0623 - val_cosine_proximity: -0.9458
# Restoring model weights from the end of the best epoch
#
# Epoch 00022: val_loss did not improve from 0.04735
# Epoch 00022: early stopping

# %% [markdown]
# #### Visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt

pd.DataFrame(history.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0,1)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(16,5))
plt.subplot(121)
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')
plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')

plt.show()

# %%
plt.figure(figsize=(16,5))
plt.subplot(121)
plt.plot(history.history['val_cosine_proximity'])
plt.plot(history.history['cosine_proximity'])
plt.title('Cosine Similarity')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')
plt.subplot(122)
plt.plot(history.history['val_mean_absolute_error'])
plt.plot(history.history['mean_absolute_error'])
plt.title('Mean Absolute Error')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')

plt.show()

# %%
plt.figure(figsize=(16,5))
plt.subplot(122)
plt.plot(history.history['val_mean_squared_error'])
plt.plot(history.history['mean_squared_error'])
plt.title('Mean Suared Error')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')

plt.show()

# %%
# %matplotlib inline
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

plot_model(model, to_file='mayowa_custom_vgg_bigdataset.png', show_shapes=True, show_layer_names=True)
img = mpimg.imread('mayowa_custom_vgg_bigdataset.png')
plt.figure(figsize=(100,70))
imgplot = plt.imshow(img)
