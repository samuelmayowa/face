# %%
from keras.applications import VGG16
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, GlobalAveragePooling2D
from keras.layers import Conv2D, MaxPooling2D, ZeroPadding2D
from keras.layers.normalization import BatchNormalization
from keras.models import Model
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Training our VGGFace Model Using Transfer Learning VGG16
#
# ### Loading the VGG16 Model

# %%
from keras.applications import vgg16

# VGG16 was designed to work on 224 x 224 pixel input images sizes
img_rows = 224
img_cols = 224

# %%
#Loads the VGG16 model 
vgg16 = VGG16(weights = 'imagenet', 
                 include_top = False, 
                 input_shape = (img_rows, img_cols, 3))

# %% [markdown]
# ### Inpsecting each layer

# %%
# Let's print our layers 
for (i,layer) in enumerate(vgg16.layers):
    print(str(i) + " "+ layer.__class__.__name__, layer.trainable)
# Out:
# 0 InputLayer False
# 1 Conv2D True
# 2 Conv2D True
# 3 MaxPooling2D True
# 4 Conv2D True
# 5 Conv2D True
# 6 MaxPooling2D True
# 7 Conv2D True
# 8 Conv2D True
# 9 Conv2D True
# 10 MaxPooling2D True
# 11 Conv2D True
# 12 Conv2D True
# 13 Conv2D True
# 14 MaxPooling2D True
# 15 Conv2D True
# 16 Conv2D True
# 17 Conv2D True
# 18 MaxPooling2D True

# %% [markdown]
# ### Let's make a function that returns our FC Head

# %%
def addTopModel(bottom_model, num_classes, D=256):
    """creates the top or head of the model that will be 
    placed ontop of the bottom layers"""
    top_model = bottom_model.output
    top_model = GlobalAveragePooling2D()(top_model)
    top_model = Dense(1024,activation='relu')(top_model)
    top_model = Dense(1024,activation='relu')(top_model)
    top_model = Dense(512,activation='relu')(top_model)
    top_model = Dense(num_classes,activation='softmax')(top_model)
    return top_model

# %% [markdown]
# #### re-sizing the image to 64 x 64

# %%
from keras.applications import VGG16

# Setting the input size now to 64 x 64 pixel 
img_rows = 64
img_cols = 64 

# Re-loads the VGG16 model without the top or FC layers
vgg16 = VGG16(weights = 'imagenet', 
                 include_top = False, 
                 input_shape = (img_rows, img_cols, 3))

# Here we freeze the last 4 layers 
# Layers are set to trainable as True by default
for layer in vgg16.layers:
    layer.trainable = False
    
# Let's print our layers 
for (i,layer) in enumerate(vgg16.layers):
    print(str(i) + " "+ layer.__class__.__name__, layer.trainable)
# Out:
# 0 InputLayer False
# 1 Conv2D False
# 2 Conv2D False
# 3 MaxPooling2D False
# 4 Conv2D False
# 5 Conv2D False
# 6 MaxPooling2D False
# 7 Conv2D False
# 8 Conv2D False
# 9 Conv2D False
# 10 MaxPooling2D False
# 11 Conv2D False
# 12 Conv2D False
# 13 Conv2D False
# 14 MaxPooling2D False
# 15 Conv2D False
# 16 Conv2D False
# 17 Conv2D False
# 18 MaxPooling2D False

# %% [markdown]
# ### Let's create our new model using an image size of 64 x 64

# %%
########Data Splitting #######

# Change the batchsize according to your system RAM
train_batchsize = 16

train_data_dir = './people'

validation_datagen = ImageDataGenerator(rescale=1./255)

datagen = ImageDataGenerator(
          rescale=1./255,
          rotation_range=30,
          shear_range=0.3,
          zoom_range=0.3,
          width_shift_range=0.4,
          height_shift_range=0.4,
          horizontal_flip=True,
          fill_mode='nearest',
          validation_split=0.2)

train_generator = datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_rows, img_cols),
        batch_size=train_batchsize,
        class_mode='categorical',
        shuffle=True,
        subset='training')

validation_generator = datagen.flow_from_directory(
        train_data_dir,
        target_size=(img_rows, img_cols),
        batch_size=train_batchsize,
        class_mode='categorical',
        shuffle=True, 
        subset='validation')
# Out:
# Found 12072 images belonging to 5714 classes.
# Found 1066 images belonging to 5714 classes.

# %%
# Re-loads the VGG16 model without the top or FC layers
vgg16 = VGG16(weights = 'imagenet', 
                 include_top = False, 
                 input_shape = (img_rows, img_cols, 3))

# %%
# Number of classes in the dataset with other parameters
num_classes = 5714
nb_train_samples = 12072
nb_validation_samples = 1066
epochs = 200
batch_size = 16

# %%
# Freeze layers
for layer in vgg16.layers:
    layer.trainable = False
    

FC_Head = addTopModel(vgg16, num_classes)

model = Model(inputs=vgg16.input, outputs=FC_Head)

print(model.summary())
print('Number of hidden layer = {}'.format(len(model.layers)))
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 64, 64, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 64, 64, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 32, 32, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 32, 32, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 32, 32, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 16, 16, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 16, 16, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 16, 16, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 8, 8, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 8, 8, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 4, 4, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 2, 2, 512)         0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              1049600
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_4 (Dense)              (None, 5714)              2931282
# =================================================================
# Total params: 19,745,682
# Trainable params: 5,030,994
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None
# Number of hidden layer = 24

# %% [markdown]
# ### Trainning Begins

# %%
from keras.optimizers import RMSprop
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
                   
checkpoint = ModelCheckpoint("./saved/big/big_dataset_vgg.h5",
                             monitor="val_loss",
                             mode="min",
                             save_best_only = True,
                             verbose=1)

earlystop = EarlyStopping(monitor = 'val_loss', 
                          min_delta = 0, 
                          patience = 5,
                          verbose = 1,
                          restore_best_weights = True)

reduce_lr = ReduceLROnPlateau(monitor = 'val_loss',
                              factor = 0.2,
                              patience = 3,
                              min_lr=0.001,
                              verbose = 1,
                              min_delta = 0.00001)

# we put our call backs into a callback list
callbacks = [checkpoint, earlystop,reduce_lr]

# Note we use a small learning rate 
model.compile(optimizer=Adam(lr=0.01), loss='categorical_crossentropy', metrics=['accuracy','mse','mae','cosine'])


history = model.fit_generator(
    train_generator,
    steps_per_epoch = nb_train_samples // batch_size,
    epochs = epochs,
    callbacks=callbacks,
    validation_data = validation_generator,
    validation_steps = nb_validation_samples // batch_size)

model.save("./saved/big/big_dataset_vgg.h5")
# Out:
# Epoch 1/200
# 754/754 [==============================] - 816s 1s/step - loss: 8.5881 - acc: 0.0342 - mean_squared_error: 1.7484e-04 - mean_absolute_error: 3.4966e-04 - cosine_proximity: -0.0353 - val_loss: 6.6639 - val_acc: 0.0985 - val_mean_squared_error: 1.7399e-04 - val_mean_absolute_error: 3.4884e-04 - val_cosine_proximity: -0.1122
#
# Epoch 00001: val_loss improved from inf to 6.66388, saving model to ./saved/big/big_dataset_vgg.h5
# Epoch 2/200
# 754/754 [==============================] - 835s 1s/step - loss: 8.1311 - acc: 0.0348 - mean_squared_error: 1.7465e-04 - mean_absolute_error: 3.4935e-04 - cosine_proximity: -0.0456 - val_loss: 6.2977 - val_acc: 0.0971 - val_mean_squared_error: 1.7334e-04 - val_mean_absolute_error: 3.4794e-04 - val_cosine_proximity: -0.1232
#
# Epoch 00002: val_loss improved from 6.66388 to 6.29769, saving model to ./saved/big/big_dataset_vgg.h5
# Epoch 3/200
# 754/754 [==============================] - 842s 1s/step - loss: 8.0520 - acc: 0.0350 - mean_squared_error: 1.7463e-04 - mean_absolute_error: 3.4923e-04 - cosine_proximity: -0.0464 - val_loss: 6.2337 - val_acc: 0.1000 - val_mean_squared_error: 1.7335e-04 - val_mean_absolute_error: 3.4798e-04 - val_cosine_proximity: -0.1248
#
# Epoch 00003: val_loss improved from 6.29769 to 6.23370, saving model to ./saved/big/big_dataset_vgg.h5
# Epoch 4/200
# 754/754 [==============================] - 850s 1s/step - loss: 8.0188 - acc: 0.0350 - mean_squared_error: 1.7463e-04 - mean_absolute_error: 3.4924e-04 - cosine_proximity: -0.0465 - val_loss: 6.2020 - val_acc: 0.0990 - val_mean_squared_error: 1.7327e-04 - val_mean_absolute_error: 3.4786e-04 - val_cosine_proximity: -0.1251
#
# Epoch 00004: val_loss improved from 6.23370 to 6.20202, saving model to ./saved/big/big_dataset_vgg.h5
# Epoch 5/200
# 754/754 [==============================] - 848s 1s/step - loss: 8.0027 - acc: 0.0351 - mean_squared_error: 1.7463e-04 - mean_absolute_error: 3.4923e-04 - cosine_proximity: -0.0466 - val_loss: 6.2134 - val_acc: 0.1000 - val_mean_squared_error: 1.7332e-04 - val_mean_absolute_error: 3.4793e-04 - val_cosine_proximity: -0.1238
#
# Epoch 00005: val_loss did not improve from 6.20202
# Epoch 6/200
# 754/754 [==============================] - 845s 1s/step - loss: 7.9916 - acc: 0.0350 - mean_squared_error: 1.7463e-04 - mean_absolute_error: 3.4923e-04 - cosine_proximity: -0.0467 - val_loss: 6.2081 - val_acc: 0.0981 - val_mean_squared_error: 1.7334e-04 - val_mean_absolute_error: 3.4796e-04 - val_cosine_proximity: -0.1246
#
# Epoch 00006: val_loss did not improve from 6.20202
# Epoch 7/200
# 754/754 [==============================] - 847s 1s/step - loss: 7.9902 - acc: 0.0350 - mean_squared_error: 1.7463e-04 - mean_absolute_error: 3.4923e-04 - cosine_proximity: -0.0465 - val_loss: 6.1980 - val_acc: 0.0943 - val_mean_squared_error: 1.7344e-04 - val_mean_absolute_error: 3.4809e-04 - val_cosine_proximity: -0.1225
#
# Epoch 00007: val_loss improved from 6.20202 to 6.19802, saving model to ./saved/big/big_dataset_vgg.h5
# Epoch 8/200
# 754/754 [==============================] - 911s 1s/step - loss: 7.9808 - acc: 0.0350 - mean_squared_error: 1.7462e-04 - mean_absolute_error: 3.4925e-04 - cosine_proximity: -0.0467 - val_loss: 6.1976 - val_acc: 0.1029 - val_mean_squared_error: 1.7324e-04 - val_mean_absolute_error: 3.4783e-04 - val_cosine_proximity: -0.1273
#
# Epoch 00008: val_loss improved from 6.19802 to 6.19760, saving model to ./saved/big/big_dataset_vgg.h5
# Epoch 9/200
# 754/754 [==============================] - 835s 1s/step - loss: 7.9849 - acc: 0.0350 - mean_squared_error: 1.7463e-04 - mean_absolute_error: 3.4924e-04 - cosine_proximity: -0.0466 - val_loss: 6.2130 - val_acc: 0.0990 - val_mean_squared_error: 1.7330e-04 - val_mean_absolute_error: 3.4790e-04 - val_cosine_proximity: -0.1244
#
# Epoch 00009: val_loss did not improve from 6.19760
# Epoch 10/200
# 754/754 [==============================] - 848s 1s/step - loss: 7.9846 - acc: 0.0346 - mean_squared_error: 1.7463e-04 - mean_absolute_error: 3.4924e-04 - cosine_proximity: -0.0463 - val_loss: 6.2253 - val_acc: 0.0924 - val_mean_squared_error: 1.7341e-04 - val_mean_absolute_error: 3.4804e-04 - val_cosine_proximity: -0.1204
#
# Epoch 00010: val_loss did not improve from 6.19760
# Epoch 11/200
# 754/754 [==============================] - 845s 1s/step - loss: 7.9789 - acc: 0.0354 - mean_squared_error: 1.7462e-04 - mean_absolute_error: 3.4923e-04 - cosine_proximity: -0.0469 - val_loss: 6.2158 - val_acc: 0.0990 - val_mean_squared_error: 1.7337e-04 - val_mean_absolute_error: 3.4800e-04 - val_cosine_proximity: -0.1242
#
# Epoch 00011: val_loss did not improve from 6.19760
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0019999999552965165.
# Epoch 12/200
# 754/754 [==============================] - 840s 1s/step - loss: 7.9240 - acc: 0.0347 - mean_squared_error: 1.7462e-04 - mean_absolute_error: 3.4926e-04 - cosine_proximity: -0.0469 - val_loss: 6.1973 - val_acc: 0.1038 - val_mean_squared_error: 1.7327e-04 - val_mean_absolute_error: 3.4789e-04 - val_cosine_proximity: -0.1285
#
# Epoch 00012: val_loss improved from 6.19760 to 6.19727, saving model to ./saved/big/big_dataset_vgg.h5
# Epoch 13/200
# 754/754 [==============================] - 1034s 1s/step - loss: 7.9283 - acc: 0.0346 - mean_squared_error: 1.7463e-04 - mean_absolute_error: 3.4924e-04 - cosine_proximity: -0.0466 - val_loss: 6.2167 - val_acc: 0.1019 - val_mean_squared_error: 1.7331e-04 - val_mean_absolute_error: 3.4793e-04 - val_cosine_proximity: -0.1256
#
# Epoch 00013: val_loss did not improve from 6.19727
# Epoch 14/200
# 754/754 [==============================] - 828s 1s/step - loss: 7.9272 - acc: 0.0347 - mean_squared_error: 1.7462e-04 - mean_absolute_error: 3.4924e-04 - cosine_proximity: -0.0469 - val_loss: 6.1841 - val_acc: 0.0971 - val_mean_squared_error: 1.7332e-04 - val_mean_absolute_error: 3.4794e-04 - val_cosine_proximity: -0.1257
#
# Epoch 00014: val_loss improved from 6.19727 to 6.18409, saving model to ./saved/big/big_dataset_vgg.h5
# Epoch 15/200
# 754/754 [==============================] - 822s 1s/step - loss: 7.9232 - acc: 0.0352 - mean_squared_error: 1.7462e-04 - mean_absolute_error: 3.4923e-04 - cosine_proximity: -0.0472 - val_loss: 6.2803 - val_acc: 0.0914 - val_mean_squared_error: 1.7347e-04 - val_mean_absolute_error: 3.4808e-04 - val_cosine_proximity: -0.1165
#
# Epoch 00015: val_loss did not improve from 6.18409
# Epoch 16/200
# 754/754 [==============================] - 808s 1s/step - loss: 7.9186 - acc: 0.0355 - mean_squared_error: 1.7461e-04 - mean_absolute_error: 3.4923e-04 - cosine_proximity: -0.0474 - val_loss: 6.2132 - val_acc: 0.0981 - val_mean_squared_error: 1.7333e-04 - val_mean_absolute_error: 3.4794e-04 - val_cosine_proximity: -0.1240
#
# Epoch 00016: val_loss did not improve from 6.18409
# Epoch 17/200
# 754/754 [==============================] - 820s 1s/step - loss: 7.9251 - acc: 0.0344 - mean_squared_error: 1.7462e-04 - mean_absolute_error: 3.4924e-04 - cosine_proximity: -0.0467 - val_loss: 6.1614 - val_acc: 0.1029 - val_mean_squared_error: 1.7323e-04 - val_mean_absolute_error: 3.4784e-04 - val_cosine_proximity: -0.1303
#
# Epoch 00017: val_loss improved from 6.18409 to 6.16141, saving model to ./saved/big/big_dataset_vgg.h5
# Epoch 18/200
# 754/754 [==============================] - 821s 1s/step - loss: 7.9252 - acc: 0.0354 - mean_squared_error: 1.7462e-04 - mean_absolute_error: 3.4923e-04 - cosine_proximity: -0.0472 - val_loss: 6.1970 - val_acc: 0.1019 - val_mean_squared_error: 1.7328e-04 - val_mean_absolute_error: 3.4789e-04 - val_cosine_proximity: -0.1265
#
# Epoch 00018: val_loss did not improve from 6.16141
# Epoch 19/200
# 754/754 [==============================] - 817s 1s/step - loss: 7.9273 - acc: 0.0347 - mean_squared_error: 1.7462e-04 - mean_absolute_error: 3.4924e-04 - cosine_proximity: -0.0468 - val_loss: 6.2577 - val_acc: 0.0886 - val_mean_squared_error: 1.7345e-04 - val_mean_absolute_error: 3.4805e-04 - val_cosine_proximity: -0.1167
#
# Epoch 00019: val_loss did not improve from 6.16141
# Epoch 20/200
# 754/754 [==============================] - 898s 1s/step - loss: 7.9212 - acc: 0.0352 - mean_squared_error: 1.7462e-04 - mean_absolute_error: 3.4922e-04 - cosine_proximity: -0.0473 - val_loss: 6.1599 - val_acc: 0.1095 - val_mean_squared_error: 1.7317e-04 - val_mean_absolute_error: 3.4778e-04 - val_cosine_proximity: -0.1332
# Epoch 00020: val_loss improved from 6.16141 to 6.15993, saving model to ./saved/big/big_dataset_vgg.h5
# Epoch 21/200
# 754/754 [==============================] - 27839s 37s/step - loss: 7.9229 - acc: 0.0351 - mean_squared_error: 1.7462e-04 - mean_absolute_error: 3.4924e-04 - cosine_proximity: -0.0470 - val_loss: 6.2343 - val_acc: 0.0914 - val_mean_squared_error: 1.7341e-04 - val_mean_absolute_error: 3.4802e-04 - val_cosine_proximity: -0.1188
#
# Epoch 00021: val_loss did not improve from 6.15993
# Epoch 22/200
# 754/754 [==============================] - 785s 1s/step - loss: 7.9291 - acc: 0.0342 - mean_squared_error: 1.7463e-04 - mean_absolute_error: 3.4925e-04 - cosine_proximity: -0.0464 - val_loss: 6.2429 - val_acc: 0.0924 - val_mean_squared_error: 1.7338e-04 - val_mean_absolute_error: 3.4799e-04 - val_cosine_proximity: -0.1204
#
# Epoch 00022: val_loss did not improve from 6.15993
# Epoch 23/200
# 754/754 [==============================] - 872s 1s/step - loss: 7.9224 - acc: 0.0352 - mean_squared_error: 1.7461e-04 - mean_absolute_error: 3.4922e-04 - cosine_proximity: -0.0473 - val_loss: 6.1974 - val_acc: 0.1057 - val_mean_squared_error: 1.7325e-04 - val_mean_absolute_error: 3.4787e-04 - val_cosine_proximity: -0.1287
#
# Epoch 00023: val_loss did not improve from 6.15993
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.001.
# Epoch 24/200
# 754/754 [==============================] - 817s 1s/step - loss: 7.9121 - acc: 0.0350 - mean_squared_error: 1.7462e-04 - mean_absolute_error: 3.4923e-04 - cosine_proximity: -0.0471 - val_loss: 6.1570 - val_acc: 0.1048 - val_mean_squared_error: 1.7325e-04 - val_mean_absolute_error: 3.4786e-04 - val_cosine_proximity: -0.1293
#
# Epoch 00024: val_loss improved from 6.15993 to 6.15704, saving model to ./saved/big/big_dataset_vgg.h5
# Epoch 25/200
# 754/754 [==============================] - 815s 1s/step - loss: 7.9224 - acc: 0.0350 - mean_squared_error: 1.7462e-04 - mean_absolute_error: 3.4923e-04 - cosine_proximity: -0.0469 - val_loss: 6.2659 - val_acc: 0.0886 - val_mean_squared_error: 1.7344e-04 - val_mean_absolute_error: 3.4806e-04 - val_cosine_proximity: -0.1174
#
# Epoch 00025: val_loss did not improve from 6.15704
# Epoch 26/200
# 754/754 [==============================] - 820s 1s/step - loss: 7.9151 - acc: 0.0349 - mean_squared_error: 1.7462e-04 - mean_absolute_error: 3.4923e-04 - cosine_proximity: -0.0470 - val_loss: 6.1928 - val_acc: 0.1038 - val_mean_squared_error: 1.7329e-04 - val_mean_absolute_error: 3.4791e-04 - val_cosine_proximity: -0.1267
#
# Epoch 00026: val_loss did not improve from 6.15704
# Epoch 27/200
# 754/754 [==============================] - 887s 1s/step - loss: 7.9158 - acc: 0.0353 - mean_squared_error: 1.7461e-04 - mean_absolute_error: 3.4923e-04 - cosine_proximity: -0.0473 - val_loss: 6.1806 - val_acc: 0.1000 - val_mean_squared_error: 1.7327e-04 - val_mean_absolute_error: 3.4789e-04 - val_cosine_proximity: -0.1277
#
# Epoch 00027: val_loss did not improve from 6.15704
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.001.
# Epoch 28/200
# 754/754 [==============================] - 822s 1s/step - loss: 7.9168 - acc: 0.0346 - mean_squared_error: 1.7462e-04 - mean_absolute_error: 3.4924e-04 - cosine_proximity: -0.0468 - val_loss: 6.2283 - val_acc: 0.0924 - val_mean_squared_error: 1.7339e-04 - val_mean_absolute_error: 3.4801e-04 - val_cosine_proximity: -0.1208
#
# Epoch 00028: val_loss did not improve from 6.15704
# Epoch 29/200
# 754/754 [==============================] - 818s 1s/step - loss: 7.9117 - acc: 0.0356 - mean_squared_error: 1.7461e-04 - mean_absolute_error: 3.4922e-04 - cosine_proximity: -0.0475 - val_loss: 6.2352 - val_acc: 0.0981 - val_mean_squared_error: 1.7335e-04 - val_mean_absolute_error: 3.4796e-04 - val_cosine_proximity: -0.1233
#
# Epoch 00029: val_loss did not improve from 6.15704
# Restoring model weights from the end of the best epoch
# Epoch 00029: early stopping

# %% [markdown]
# ### Visual Look of our custom model

# %%
# %matplotlib inline
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

plot_model(model, to_file='mayowa_custom_vgg_bigdataset.png', show_shapes=True, show_layer_names=True)
img = mpimg.imread('mayowa_custom_vgg_bigdataset.png')
plt.figure(figsize=(100,70))
imgplot = plt.imshow(img)

# %% [markdown]
# ### Performance Analysis

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(16,5))
plt.subplot(121)
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')
plt.subplot(122)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')

plt.show()

# %%
plt.figure(figsize=(16,5))
plt.subplot(121)
plt.plot(history.history['cosine_proximity'])
plt.plot(history.history['val_cosine_proximity'])
plt.title('Cosine Similarity')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')
plt.subplot(122)
plt.plot(history.history['mean_absolute_error'])
plt.plot(history.history['val_mean_absolute_error'])
plt.title('Mean Absolute Error')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper right')

plt.show()

# %%
plt.figure(figsize=(16,5))
plt.subplot(121)
plt.plot(history.history['mean_squared_error'])
plt.plot(history.history['val_mean_squared_error'])
plt.title('Mean Squared Error')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='lower right')
